# %% [markdown]
# # API Key 확인

# %%
# !pip install openai langchain langchain-openai

import os
os.environ['OPENAI_API_KEY'] = "" #<---------------- API 키를 복사하세요

# %%
from langchain_openai import ChatOpenAI

# model
llm = ChatOpenAI(model="gpt-3.5-turbo-0125")

# chain
print(llm.invoke("의사들에게 LLM은 어떠한 도움을 줄 수 있을까?").content)
# Out:
# 의사들에게 LLM은 다음과 같은 도움을 줄 수 있습니다:
#
# 1. 전문적인 법률 지식: LLM 학위를 취득한 변호사는 의료 법률 분야에 대한 전문적인 지식과 이해를 갖고 있습니다. 이러한 지식을 토대로 의사들에게 법률적인 문제나 규제에 대한 조언을 제공할 수 있습니다.
#
# 2. 의료 법률 상담: LLM을 취득한 변호사는 의료 법률 분야에 대한 상담을 제공할 수 있습니다. 의사들이 진료 실무나 환자와의 관계에서 발생할 수 있는 법률적인 문제에 대해 상담을 받을 수 있습니다.
#
# 3. 법률 문서 작성: LLM을 취득한 변호사는 의사들을 위해 법률 문서를 작성하고 검토할 수 있습니다. 예를 들어, 의사들이 환자와의 계약이나 의료 기록 문서를 작성할 때 법률적인 측면을 고려하여 도와줄 수 있습니다.
#
# 4. 법률 교육: LLM을 취득한 변호사는 의사들에게 의료 법률에 대한 교육을 제공할 수 있습니다. 이를 통해 의사들이 법률적인 문제에 대해 보다 잘 이해하고 대비할 수 있도록 도와줄 수 있습니다.
#
# 5. 법률 소송 대리: LLM을 취득한 변호사는 의사들이 소송에 휩쓸렸을 때 변호사로서 대리를 해 줄 수 있습니다. 의료 분야에서 법률 소송이 발생했을 때 전문적인 변호사의 도움을 받는 것은 매우 중요합니다.

# %% [markdown]
# #
